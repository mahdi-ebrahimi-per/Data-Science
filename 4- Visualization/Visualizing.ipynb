# %% [markdown]
# # Visualizing

# %%
#import Librarys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = pd.read_csv('coin_Bitcoin.csv')
a.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
class Visualizing:
    def __init__(self, csv_Addr):
        # import all csv file as df
        self.csv_Addr = csv_Addr
        self.df = pd.read_csv(csv_Addr)

        

    def show_styleNames(self):
        names = [
            "default","classic","Solarize_Light2",
            "_classic_test_patch","bmh","dark_background","fast",
            "fivethirtyeight","ggplot","grayscale","seaborn","seaborn-bright",
            "seaborn-colorblind","seaborn-dark","seaborn-dark-palette",
            "seaborn-darkgrid","seaborn-deep","seaborn-muted",
            "seaborn-notebook","seaborn-paper","seaborn-pastel",
            "seaborn-poster","saeborn-talk","seaborn-ticks","saeborn-white",
            "saeborn-whitegrid","tableau-colorblind10"]
        return names

    def use_style(self, name):
        try:
            plt.style.use(name)
            
        except:
            raise ValueError("wrong style name. see \"Visualizing.show_styleNames()\"")

    def slice_column(self, column, slicing = []):
        if column and slicing:
            if len(slicing) == 2:
                try:
                    self.befor = self.df[column]
                    slicing = slice(slicing[0], slicing[1])
                    self.df[column] = self.df[column][slicing]

                except:
                    raise ValueError("column name is incorrect")

            else:
                raise ValueError("slincing argument takes 2 but you take wrong")        




    def plot(self, columns = []):
        if columns:
            if type(columns) == list:
                try:
                    for column in columns:
                        plt.plot(self.df[column], label=column)
                
                    plt.legend()
                    plt.show()

                except:
                    raise ValueError('column name or names is not correct')    

            else:
                raise ValueError(' "columns" argument must be list ')        


        else:
            raise ValueError("fill 'columns' argument")        


    def scatter(self, variable_x, variable_y):
        try:
            variable_x = self.df[variable_x]
            variable_y = self.df[variable_y]
        except:
            pass
        
        try:
            plt.scatter(variable_x, variable_y)
            plt.show()
        
        except:
            raise ValueError("arguments variables not correct!")

    
    def stack(self, Variables=[]):
        # colors = ['red', 'blue', 'black', 'green', 'cyan', 'megenta', 'yellow', 'white']
    
        # plt.stackplot(Variables)
        # plt.plot([], [], linewidth=5)
        
        # plt.show()
        pass

    def pie(self):
        pass

# %%
sample = Visualizing('coin_Bitcoin.csv')

print(sample.show_styleNames())
# sample.use_style("seaborn-dark-palette")

# sample.plot(["Low", "High", "Close"])

sample.scatter("Low", "High")
# Out:
# ['default', 'classic', 'Solarize_Light2', '_classic_test_patch', 'bmh', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'saeborn-talk', 'seaborn-ticks', 'saeborn-white', 'saeborn-whitegrid', 'tableau-colorblind10']
